# %% [markdown]
# # Using Fully Connected  NN to Make Predictions

# %%
import matplotlib.pyplot as plt

sys.path.append(r'../atm_demand')
from feature_generation import *

from sklearn.model_selection import train_test_split

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Preprocessing Plan:
# * Use Functional API
# * Treat the categorical and numerical features differently.
#     * One-hot: Is_Weekday, Is_Weekend, is_ramazan, ramazan_in_7_days, is_kurban, kurban_in_7_days
#     * Embed  : Day_Index, curr_month_1_delta, curr_month_15_delta, next_month_1_delta
#     * Numerical (normalized): Rest
#     * Sources for Functional API:
#         * [How to slice an input in keras?](https://datascience.stackexchange.com/questions/86740/how-to-slice-an-input-in-keras)
#         * [Sequential API vs Functional API model in Keras](https://hanifi.medium.com/sequential-api-vs-functional-api-model-in-keras-266823d7cd5e)

# %% [markdown]
# ### Is_Weekday, Is_Weekend, is_ramazan, ramazan_in_7_days, is_kurban, kurban_in_7_days
# No change, use directly as one-hot

# %%
one_hots = layers.Input(shape=[6])

# %% [markdown]
# ### Day_Index, next_month_1_delta
# * [Embedding](https://keras.io/api/layers/core_layers/embedding/): Embed the index to dense vector

# %%
day_index_feature  = layers.Input(shape=[1])
day_index_embedded = layers.Embedding(input_dim=7, output_dim=10)(day_index_feature)

delta_feature  = layers.Input(shape=[1])
delta_embedded = layers.Embedding(input_dim=31, output_dim=50)(delta_feature)

embeddeds = layers.Concatenate()([day_index_embedded, delta_embedded])
embeddeds_flat = layers.Flatten()(embeddeds)

# %% [markdown]
# ### Numericals
# * [BatchNormalization layer](https://keras.io/api/layers/normalization_layers/batch_normalization/): Normalize each feature. Features are last values, trend and averages of CashIn and CashOut.

# %%
features_to_normalize = layers.Input(shape=[60])
normalized            = layers.BatchNormalization()(features_to_normalize)

# %% [markdown]
# ### Concatenating All Paths Together

# %%
preprocessed = layers.Concatenate()([one_hots, embeddeds_flat, normalized])

# %% [markdown]
# Draw the model so far:

# %%
preprocessing_model = keras.Model(inputs=[one_hots, day_index_feature, delta_feature, features_to_normalize], outputs=[preprocessed] )
#from tensorflow.keras.utils import plot_model
#plot_model(preprocessing_model, show_shapes=True, show_layer_names=True)
preprocessing_model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 10)        70          input_2[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 50)        1550        input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1, 60)        0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 60)]         0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 60)           0           concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 60)           240         input_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 126)          0           input_1[0][0]
#                                                                  flatten[0][0]
#                                                                  batch_normalization[0][0]
# ==================================================================================================
# Total params: 1,860
# Trainable params: 1,740
# Non-trainable params: 120
# __________________________________________________________________________________________________

# %% [markdown]
# ## Rest of The Model

# %%
dropout1 = layers.Dropout(0.2)(preprocessed)
dense1   = layers.Dense(128, activation='relu')(dropout1)
dropout2 = layers.Dropout(0.2)(dense1)
dense2   = layers.Dense(32, activation='relu')(dropout2)
dense3   = layers.Dense(16, activation='relu')(dense2)
nn_output = layers.Dense(1)(dense3)

# %%
nn_model = keras.Model(inputs=[one_hots, day_index_feature, delta_feature, features_to_normalize], outputs=[nn_output] )
nn_model.summary()
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 10)        70          input_2[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 50)        1550        input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1, 60)        0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 60)]         0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 60)           0           concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 60)           240         input_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 126)          0           input_1[0][0]
#                                                                  flatten[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 126)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          16256       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 32)           4128        dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 16)           528         dense_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            17          dense_10[0][0]
# ==================================================================================================
# Total params: 22,789
# Trainable params: 22,669
# Non-trainable params: 120
# __________________________________________________________________________________________________

# %%
nn_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mape')

# %% [markdown]
# ## Arranging Data

# %%
df = pd.read_csv("../atm_demand/DATA_sample_atm.csv")
targets = ['CashIn', 'CashOut']
atm_df = get_atm(df, 26637)
atm_df = atm_df[:-135]
atm_df = clean_data(atm_df, drop_zeros=True)
feature_set = get_feature_sets(atm_df, ['CashIn', 'CashOut'])

# %%
feature_set.columns
# Out:
# Index(['CashIn', 'CashOut', 'Day_Index', 'Day_0', 'Day_1', 'Day_2', 'Day_3',
#        'Day_4', 'Day_5', 'Day_6', 'Is_Weekday', 'Is_Weekend',
#        'CashIn_average_7', 'CashIn_average_30', 'CashOut_average_7',
#        'CashOut_average_30', 'curr_month_1_delta', 'curr_month_15_delta',
#        'next_month_1_delta', 'CashIn_trend_7', 'CashOut_trend_7', 'is_ramazan',
#        'ramazan_in_7_days', 'is_kurban', 'kurban_in_7_days', 'CashIn_t-1',
#        'CashIn_t-2', 'CashIn_t-3', 'CashIn_t-4', 'CashIn_t-5', 'CashIn_t-6',
#        'CashIn_t-7', 'CashIn_t-8', 'CashIn_t-9', 'CashIn_t-10', 'CashIn_t-11',
#        'CashIn_t-12', 'CashIn_t-13', 'CashIn_t-14', 'CashOut_t-1',
#        'CashOut_t-2', 'CashOut_t-3', 'CashOut_t-4', 'CashOut_t-5',
#        'CashOut_t-6', 'CashOut_t-7', 'CashOut_t-8', 'CashOut_t-9',
#        'CashOut_t-10', 'CashOut_t-11', 'CashOut_t-12', 'CashOut_t-13',
#        'CashOut_t-14', 'CashOut_t-15', 'CashOut_t-16', 'CashOut_t-17',
#        'CashOut_t-18', 'CashOut_t-19', 'CashOut_t-20', 'CashOut_t-21',
#        'CashOut_t-22', 'CashOut_t-23', 'CashOut_t-24', 'CashOut_t-25',
#        'CashOut_t-26', 'CashOut_t-27', 'CashOut_t-28', 'CashOut_t-29',
#        'CashOut_t-30', 'CashOut_t-31', 'CashOut_t-32', 'CashOut_t-33',
#        'CashOut_t-34', 'CashOut_t-35', 'CashOut_t-36', 'CashOut_t-37',
#        'CashOut_t-38', 'CashOut_t-39', 'CashOut_t-40'],
#       dtype='object')

# %%
def get_input_sets(df):
    one_hot_features    = df['Is_Weekday, Is_Weekend, is_ramazan, ramazan_in_7_days, is_kurban, kurban_in_7_days'.split(', ')].astype('float32')
    day_index           = df['Day_Index']
    delta               = df['next_month_1_delta'] - 1
    normalized_features = df[['CashIn_trend_7', 'CashOut_trend_7', 'CashIn_t-1',
    'CashIn_t-2', 'CashIn_t-3', 'CashIn_t-4', 'CashIn_t-5', 'CashIn_t-6',
    'CashIn_t-7', 'CashIn_t-8', 'CashIn_t-9', 'CashIn_t-10', 'CashIn_t-11',
    'CashIn_t-12', 'CashIn_t-13', 'CashIn_t-14', 'CashOut_t-1',
    'CashOut_t-2', 'CashOut_t-3', 'CashOut_t-4', 'CashOut_t-5',
    'CashOut_t-6', 'CashOut_t-7', 'CashOut_t-8', 'CashOut_t-9',
    'CashOut_t-10', 'CashOut_t-11', 'CashOut_t-12', 'CashOut_t-13',
    'CashOut_t-14', 'CashOut_t-15', 'CashOut_t-16', 'CashOut_t-17',
    'CashOut_t-18', 'CashOut_t-19', 'CashOut_t-20', 'CashOut_t-21',
    'CashOut_t-22', 'CashOut_t-23', 'CashOut_t-24', 'CashOut_t-25',
    'CashOut_t-26', 'CashOut_t-27', 'CashOut_t-28', 'CashOut_t-29',
    'CashOut_t-30', 'CashOut_t-31', 'CashOut_t-32', 'CashOut_t-33',
    'CashOut_t-34', 'CashOut_t-35', 'CashOut_t-36', 'CashOut_t-37',
    'CashOut_t-38', 'CashOut_t-39', 'CashOut_t-40', 'CashIn_average_7',
    'CashIn_average_30', 'CashOut_average_7', 'CashOut_average_30']].astype('float32')

    return [one_hot_features, day_index, delta, normalized_features]

# %%
TARGET = 'CashIn'
X_train, X_test, y_train, y_test = train_test_split(feature_set[feature_set.columns[2:]], feature_set[TARGET], shuffle = False)

# %%
train_inputs = get_input_sets(X_train)
test_inputs  = get_input_sets(X_test)

# %% [markdown]
# ## Training

# %%
history = nn_model.fit(train_inputs, 
            y_train,
            batch_size=32,
            epochs=100,
            validation_data=(test_inputs, y_test),
            verbose = 1)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 0s 7ms/step - loss: 66.6305 - val_loss: 78.6109
# Epoch 2/100
# 34/34 [==============================] - 0s 2ms/step - loss: 55.7182 - val_loss: 40.9502
# Epoch 3/100
# 34/34 [==============================] - 0s 2ms/step - loss: 47.1261 - val_loss: 42.2064
# Epoch 4/100
# 34/34 [==============================] - 0s 2ms/step - loss: 44.9312 - val_loss: 46.7123
# Epoch 5/100
# 34/34 [==============================] - 0s 2ms/step - loss: 45.1232 - val_loss: 42.4387
# Epoch 6/100
# 34/34 [==============================] - 0s 2ms/step - loss: 40.6448 - val_loss: 42.6387
# Epoch 7/100
# 34/34 [==============================] - 0s 2ms/step - loss: 41.1020 - val_loss: 45.0255
# Epoch 8/100
# 34/34 [==============================] - 0s 2ms/step - loss: 39.7183 - val_loss: 40.0847
# Epoch 9/100
# 34/34 [==============================] - 0s 2ms/step - loss: 42.4589 - val_loss: 36.8894
# Epoch 10/100
# 34/34 [==============================] - 0s 2ms/step - loss: 38.6118 - val_loss: 41.0884
# Epoch 11/100
# 34/34 [==============================] - 0s 2ms/step - loss: 41.5998 - val_loss: 50.4272
# Epoch 12/100
# 34/34 [==============================] - 0s 3ms/step - loss: 40.9410 - val_loss: 39.9764
# Epoch 13/100
# 34/34 [==============================] - 0s 2ms/step - loss: 38.6730 - val_loss: 38.5766
# Epoch 14/100
# 34/34 [==============================] - 0s 2ms/step - loss: 35.5723 - val_loss: 51.8346
# Epoch 15/100
# 34/34 [==============================] - 0s 2ms/step - loss: 37.2799 - val_loss: 38.4124
# Epoch 16/100
# 34/34 [==============================] - 0s 2ms/step - loss: 36.2266 - val_loss: 40.3582
# Epoch 17/100
# 34/34 [==============================] - 0s 2ms/step - loss: 37.6307 - val_loss: 43.8229
# Epoch 18/100
# 34/34 [==============================] - 0s 2ms/step - loss: 35.2250 - val_loss: 47.2021
# Epoch 19/100
# 34/34 [==============================] - 0s 2ms/step - loss: 34.9921 - val_loss: 44.5968
# Epoch 20/100
# 34/34 [==============================] - 0s 2ms/step - loss: 35.4506 - val_loss: 41.9861
# Epoch 21/100
# 34/34 [==============================] - 0s 2ms/step - loss: 33.2492 - val_loss: 40.0148
# Epoch 22/100
# 34/34 [==============================] - 0s 2ms/step - loss: 33.8143 - val_loss: 40.8549
# Epoch 23/100
# 34/34 [==============================] - 0s 2ms/step - loss: 34.0636 - val_loss: 42.7195
# Epoch 24/100
# 34/34 [==============================] - 0s 2ms/step - loss: 32.1291 - val_loss: 42.5693
# Epoch 25/100
# 34/34 [==============================] - 0s 2ms/step - loss: 31.4761 - val_loss: 45.6328
# Epoch 26/100
# 34/34 [==============================] - 0s 2ms/step - loss: 32.7669 - val_loss: 39.1227
# Epoch 27/100
# 34/34 [==============================] - 0s 2ms/step - loss: 32.2660 - val_loss: 40.2711
# Epoch 28/100
# 34/34 [==============================] - 0s 2ms/step - loss: 33.3021 - val_loss: 40.4392
# Epoch 29/100
# 34/34 [==============================] - 0s 2ms/step - loss: 33.7341 - val_loss: 40.3883
# Epoch 30/100
# 34/34 [==============================] - 0s 2ms/step - loss: 31.8705 - val_loss: 44.3000
# Epoch 31/100
# 34/34 [==============================] - 0s 2ms/step - loss: 32.0636 - val_loss: 46.8839
# Epoch 32/100
# 34/34 [==============================] - 0s 2ms/step - loss: 30.8150 - val_loss: 43.5911
# Epoch 33/100
# 34/34 [==============================] - 0s 2ms/step - loss: 31.1387 - val_loss: 40.6494
# Epoch 34/100
# 34/34 [==============================] - 0s 2ms/step - loss: 32.3564 - val_loss: 44.2880
# Epoch 35/100
# 34/34 [==============================] - 0s 2ms/step - loss: 31.7101 - val_loss: 63.0577
# Epoch 36/100
# 34/34 [==============================] - 0s 2ms/step - loss: 66.9449 - val_loss: 44.7770
# Epoch 37/100
# 34/34 [==============================] - 0s 2ms/step - loss: 36.1375 - val_loss: 46.3060
# Epoch 38/100
# 34/34 [==============================] - 0s 2ms/step - loss: 31.1667 - val_loss: 44.1434
# Epoch 39/100
# 34/34 [==============================] - 0s 2ms/step - loss: 30.7799 - val_loss: 43.3645
# Epoch 40/100
# 34/34 [==============================] - 0s 2ms/step - loss: 32.1997 - val_loss: 40.6298
# Epoch 41/100
# 34/34 [==============================] - 0s 2ms/step - loss: 31.6364 - val_loss: 48.2444
# Epoch 42/100
# 34/34 [==============================] - 0s 2ms/step - loss: 30.9830 - val_loss: 45.6650
# Epoch 43/100
# 34/34 [==============================] - 0s 2ms/step - loss: 31.5759 - val_loss: 41.9934
# Epoch 44/100
# 34/34 [==============================] - 0s 2ms/step - loss: 32.3728 - val_loss: 49.4598
# Epoch 45/100
# 34/34 [==============================] - 0s 2ms/step - loss: 29.5448 - val_loss: 42.5772
# Epoch 46/100
# 34/34 [==============================] - 0s 2ms/step - loss: 30.6122 - val_loss: 46.3395
# Epoch 47/100
# 34/34 [==============================] - 0s 2ms/step - loss: 31.2798 - val_loss: 46.5400
# Epoch 48/100
# 34/34 [==============================] - 0s 2ms/step - loss: 30.7381 - val_loss: 56.5900
# Epoch 49/100
# 34/34 [==============================] - 0s 2ms/step - loss: 33.9508 - val_loss: 42.3480
# Epoch 50/100
# 34/34 [==============================] - 0s 2ms/step - loss: 29.7557 - val_loss: 46.2183
# Epoch 51/100
# 34/34 [==============================] - 0s 2ms/step - loss: 42.2978 - val_loss: 70.8943
# Epoch 52/100
# 34/34 [==============================] - 0s 2ms/step - loss: 30.1326 - val_loss: 44.7390
# Epoch 53/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.7400 - val_loss: 57.0085
# Epoch 54/100
# 34/34 [==============================] - 0s 2ms/step - loss: 29.8424 - val_loss: 49.6987
# Epoch 55/100
# 34/34 [==============================] - 0s 2ms/step - loss: 31.5915 - val_loss: 42.1126
# Epoch 56/100
# 34/34 [==============================] - 0s 2ms/step - loss: 32.7351 - val_loss: 49.1232
# Epoch 57/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.9156 - val_loss: 43.6171
# Epoch 58/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.6617 - val_loss: 41.9344
# Epoch 59/100
# 34/34 [==============================] - 0s 2ms/step - loss: 29.5245 - val_loss: 49.8761
# Epoch 60/100
# 34/34 [==============================] - 0s 2ms/step - loss: 36.1212 - val_loss: 54.2600
# Epoch 61/100
# 34/34 [==============================] - 0s 2ms/step - loss: 32.2136 - val_loss: 44.2766
# Epoch 62/100
# 34/34 [==============================] - 0s 2ms/step - loss: 30.2986 - val_loss: 47.3440
# Epoch 63/100
# 34/34 [==============================] - 0s 2ms/step - loss: 29.7425 - val_loss: 55.6592
# Epoch 64/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.6794 - val_loss: 42.2485
# Epoch 65/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.3237 - val_loss: 41.0458
# Epoch 66/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.6945 - val_loss: 46.4143
# Epoch 67/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.0103 - val_loss: 48.4165
# Epoch 68/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.5030 - val_loss: 50.1782
# Epoch 69/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.0493 - val_loss: 49.8587
# Epoch 70/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.7491 - val_loss: 46.7025
# Epoch 71/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.7979 - val_loss: 44.2369
# Epoch 72/100
# 34/34 [==============================] - 0s 2ms/step - loss: 30.9643 - val_loss: 42.0781
# Epoch 73/100
# 34/34 [==============================] - 0s 3ms/step - loss: 28.8926 - val_loss: 43.5233
# Epoch 74/100
# 34/34 [==============================] - 0s 3ms/step - loss: 27.9060 - val_loss: 47.2597
# Epoch 75/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.9235 - val_loss: 44.0673
# Epoch 76/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.6312 - val_loss: 46.5094
# Epoch 77/100
# 34/34 [==============================] - 0s 2ms/step - loss: 25.8864 - val_loss: 44.9455
# Epoch 78/100
# 34/34 [==============================] - 0s 2ms/step - loss: 26.2928 - val_loss: 47.6414
# Epoch 79/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.9205 - val_loss: 53.8767
# Epoch 80/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.2839 - val_loss: 42.3699
# Epoch 81/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.7219 - val_loss: 45.7759
# Epoch 82/100
# 34/34 [==============================] - 0s 2ms/step - loss: 26.8119 - val_loss: 46.8906
# Epoch 83/100
# 34/34 [==============================] - 0s 2ms/step - loss: 26.4511 - val_loss: 43.3791
# Epoch 84/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.6947 - val_loss: 46.9786
# Epoch 85/100
# 34/34 [==============================] - 0s 2ms/step - loss: 25.9561 - val_loss: 51.7037
# Epoch 86/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.2795 - val_loss: 54.0620
# Epoch 87/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.9569 - val_loss: 45.8176
# Epoch 88/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.9879 - val_loss: 50.1560
# Epoch 89/100
# 34/34 [==============================] - 0s 2ms/step - loss: 26.1076 - val_loss: 42.5559
# Epoch 90/100
# 34/34 [==============================] - 0s 2ms/step - loss: 26.1867 - val_loss: 43.0279
# Epoch 91/100
# 34/34 [==============================] - 0s 2ms/step - loss: 26.4834 - val_loss: 50.2402
# Epoch 92/100
# 34/34 [==============================] - 0s 2ms/step - loss: 27.7728 - val_loss: 44.8070
# Epoch 93/100
# 34/34 [==============================] - 0s 2ms/step - loss: 26.4453 - val_loss: 43.1695
# Epoch 94/100
# 34/34 [==============================] - 0s 2ms/step - loss: 26.8559 - val_loss: 41.9087
# Epoch 95/100
# 34/34 [==============================] - 0s 2ms/step - loss: 28.5243 - val_loss: 47.5303
# Epoch 96/100
# 34/34 [==============================] - 0s 2ms/step - loss: 26.3566 - val_loss: 51.9613
# Epoch 97/100
# 34/34 [==============================] - 0s 2ms/step - loss: 25.6658 - val_loss: 49.9217
# Epoch 98/100
# 34/34 [==============================] - 0s 2ms/step - loss: 26.5287 - val_loss: 54.3318
# Epoch 99/100
# 34/34 [==============================] - 0s 2ms/step - loss: 25.3117 - val_loss: 50.6009
# Epoch 100/100
# 34/34 [==============================] - 0s 2ms/step - loss: 25.7246 - val_loss: 49.2347

# %%
def plot_history(history):
    plt.figure(figsize=(10,4))
    for key in history.history:
        plt.plot(history.history[key], label = key)
    plt.legend()
    plt.show()

# %%
plot_history(history)

# %%
"min_loss: %.4f, min_val_loss: %.4f" % (min(history.history['loss']), min(history.history['val_loss']))
# Out:
# 'min_loss: 25.3117, min_val_loss: 36.8894'

# %% [markdown]
# ### Comparing with Previous Methods
#
# | Model | Train Error | Test Error | All Set Error |
# | - | - | - | - |
# | Base | - | - | 78.8 |
# | Random Forest | 23.9 | 47.0 | - |
# | LGBM | - | 48.7 | - |
# | TF Custom RNN | - | - | 70.7 |
# | Keras, PP + Fully Connected (with one dropout layer) | 21.7 | 37.8 | - |
# | Keras, PP + Fully Connected (with two dropout layers) | 25.3 | 36.9 | - |

# %%
from forecasting import get_error_with_freq
from plotting import draw_error_over_time

# %%
def draw_model_error(model, X, y_actual, error_freq='w', split_from=None):

    y_pred = pd.Series(model.predict(X).reshape(-1), index=y_actual.index)
    weekly_errors = get_error_with_freq(y_actual, y_pred, error_freq)
    draw_error_over_time(y_actual, y_pred, weekly_errors, split_from)

# %%
draw_model_error(nn_model, get_input_sets(feature_set[feature_set.columns[2:]]), feature_set[TARGET])
